# %% [markdown]
# # Example Usage

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from coscientist.framework import CoscientistConfig, CoscientistFramework
from coscientist.global_state import CoscientistState, CoscientistStateManager

# %%
goal = "How does the gut microbiome influence rheumatoid arthritis and can probiotics help to mitigate symptoms? If so, which ones are promising?"
initial_state = CoscientistState(goal=goal)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 goal = "How does the gut microbiome influence rheumatoid arthritis and can probiotics help to mitigate symptoms? If so, which ones are promising?"
# ----> 2 initial_state = CoscientistState(goal=goal)
#
# File ~/sundai/coscientist-swarm/coscientist/global_state.py:98, in CoscientistState.__init__(self, goal)
#      96 # Check if directory already exists
#      97 if os.path.exists(self._output_dir):
# ---> 98     raise FileExistsError(
#      99         f"Directory for goal already exists: {self._output_dir}\n"
#     100         f"Please use CoscientistState.load_latest(goal='{goal}') to resume, "
#     101         f"or call CoscientistState.clear_goal_directory('{goal}') to start fresh."
#     102     )
#     104 # Create the directory
#     105 Path(self._output_dir).mkdir(parents=True, exist_ok=True)
#
# FileExistsError: Directory for goal already exists: /Users/pierre/.coscientist/a70b1ed443ec
# Please use CoscientistState.load_latest(goal='How does the gut microbiome influence rheumatoid arthritis and can probiotics help to mitigate symptoms? If so, which ones are promising?') to resume, or call CoscientistState.clear_goal_directory('How does the gut microbiome influence rheumatoid arthritis and can probiotics help to mitigate symptoms? If so, which ones are promising?') to start fresh.

# %%
config = CoscientistConfig()
state_manager = CoscientistStateManager(initial_state)
cosci = CoscientistFramework(config, state_manager)

# %%
final_report, final_meta_review = await cosci.run()
